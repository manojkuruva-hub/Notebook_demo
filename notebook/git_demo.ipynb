# %% [markdown]
# # Jupyter Git Demo
#
# Use this notebook to test Git changes, commits, pushes, and branches.

# %%
print("Hello from Jupyter Git Demo")

# %%
import json

with open('../testdata/users.json', encoding='utf-8') as file:
    data = json.load(file)

data

# %%
for user in data['users']:
    print(user['id'], user['name'], user['role'])

# %%
# Git commands for testing
# !git status
# !git log --oneline -5
